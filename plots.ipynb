# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# Image 3: Cameraman

# %%
Image= 'Cameraman'

# Noise levels
sigma = np.array([5, 10, 20, 30, 40, 50])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([31.78, 28.49, 22.94, 19.41, 16.91, 15.27])
spgl_bpdn_ssim = np.array([0.595, 0.466, 0.347, 0.276, 0.228, 0.191])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([33.21, 29.16, 23.58, 20.04, 17.45, 15.73])
spgl_lasso_ssim = np.array([0.608, 0.475, 0.352, 0.278, 0.227, 0.195])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([32.24, 28.90, 23.05, 19.59, 17.14, 15.19])
elastic_net_ssim = np.array([0.591, 0.473, 0.347, 0.277, 0.229, 0.191])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.subplot(1, 2, 1)
plt.plot(sigma, spgl_bpdn_psnr, label='SPGL_BPDN PSNR', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='SPGL_LASSO PSNR', marker='o')
plt.plot(sigma, elastic_net_psnr, label='ELASTIC_Net PSNR', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('PSNR')
plt.title('PSNR vs Noise Level: PCA denoising')
plt.legend()
plt.grid(True)

# Plot SSIM for all methods
plt.subplot(1, 2, 2)
plt.plot(sigma, spgl_bpdn_ssim, label='SPGL_BPDN SSIM', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='SPGL_LASSO SSIM', marker='o')
plt.plot(sigma, elastic_net_ssim, label='ELASTIC_Net SSIM', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('SSIM')
plt.title('SSIM vs Noise Level: PCA denoising')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
Image= 'Cameraman'

# Noise levels
sigma = np.array([5, 10, 20, 30, 40, 50])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([31.78, 28.49, 22.94, 19.41, 16.91, 15.27])
spgl_bpdn_ssim = np.array([0.595, 0.466, 0.347, 0.276, 0.228, 0.191])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([33.21, 29.16, 23.58, 20.04, 17.45, 15.73])
spgl_lasso_ssim = np.array([0.608, 0.475, 0.352, 0.278, 0.227, 0.195])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([32.24, 28.90, 23.05, 19.59, 17.14, 15.19])
elastic_net_ssim = np.array([0.591, 0.473, 0.347, 0.277, 0.229, 0.191])

#NLM Denoising with h=0.01, window 250. Had a better result for sigma=10 with h=0.009 and window 300.
NLM_psnr = np.array([27.8, 23.37, 19.89, 17.92, 15.73, 14.26])
NLM_ssim = np.array([0.325, 0.243, 0.156, 0.123, 0.089, 0.059])

#Adding Gaussian Noise and seeing the PSNR/SSIM at the input
Noisy_psnr = np.array([34.32, 28.49, 22.61, 19.07, 16.74, 14.89])
Noisy_ssim = np.array([0.611, 0.471, 0.348, 0.275, 0.228, 0.190])


# The plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods

plt.plot(sigma, spgl_lasso_psnr, label='PSP- with NNC Lasso', marker='o')
plt.plot(sigma, elastic_net_psnr, label='PSP- with NN Lasso', marker='o')
plt.plot(sigma, spgl_bpdn_psnr, label='PSP- with BPDN', marker='o')
plt.plot(sigma, NLM_psnr, label='NLM', marker='o')

plt.xlabel('AWGN standard deviation σ (in pixels)', fontsize= 20)
plt.ylabel('PSNR', fontsize= 20)
# plt.title('PSNR vs Noise Level: Denoising from Patched Subspace Projection',fontsize= 16)
plt.legend(fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)


# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create the SSIM plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods

plt.plot(sigma, spgl_bpdn_ssim, label='BPDN', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='NNC Lasso', marker='o')
plt.plot(sigma, elastic_net_ssim, label='NN Lasso', marker='o')
plt.plot(sigma, NLM_ssim, label='NLM', marker='o')

plt.xlabel('AWGN standard deviation σ (in pixels)', fontsize= 20)
plt.ylabel('SSIM', fontsize= 20)
# plt.title('PSNR vs Noise Level: Denoising from Patched Subspace Projection',fontsize= 16)
plt.legend(fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)


# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create the PSNR plot with noise
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods

plt.plot(sigma, spgl_bpdn_psnr, label='BPDN', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='NNC Lasso', marker='o')
plt.plot(sigma, elastic_net_psnr, label='NN Lasso', marker='o')
# plt.plot(sigma, NLM_psnr, label='NLM', marker='o')
plt.plot(sigma, Noisy_psnr, label='Noisy', marker='o')

plt.xlabel('AWGN standard deviation σ (in pixels)', fontsize= 20)
plt.ylabel('PSNR', fontsize= 20)
# plt.title('PSNR vs Noise Level: Denoising from Patched Subspace Projection',fontsize= 16)
plt.legend(fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)


# Show the plot
plt.tight_layout()
plt.show()

# %%
# SSIM Plot with the noise input
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods

plt.plot(sigma, spgl_bpdn_ssim, label='BPDN', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='NNC Lasso', marker='o')
plt.plot(sigma, elastic_net_ssim, label='NN Lasso', marker='o')
plt.plot(sigma, NLM_ssim, label='NLM', marker='o')
plt.plot(sigma, Noisy_ssim, label='Noisy', marker='o')

plt.xlabel('AWGN standard deviation σ (in pixels)', fontsize= 20)
plt.ylabel('SSIM', fontsize= 20)
# plt.title('PSNR vs Noise Level: Denoising from Patched Subspace Projection',fontsize= 16)
plt.legend(fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)


# Show the plot
plt.tight_layout()
plt.show()

# %%
# SSIM Plot with the noise input
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods

plt.plot(sigma, spgl_bpdn_ssim, label='BPDN', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='NNC Lasso', marker='o')
plt.plot(sigma, elastic_net_ssim, label='NN Lasso', marker='o')
# plt.plot(sigma, NLM_ssim, label='NLM', marker='o')
plt.plot(sigma, Noisy_ssim, label='Noisy', marker='o')

plt.xlabel('AWGN standard deviation σ (in pixels)', fontsize= 20)
plt.ylabel('SSIM', fontsize= 20)
# plt.title('PSNR vs Noise Level: Denoising from Patched Subspace Projection',fontsize= 16)
plt.legend(fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)


# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Image 6: Rice

# %%
Image= 'Rice'

# Noise levels
sigma = np.array([5, 10, 20, 30, 40, 50, 100])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([31.39, 28.28, 23.05, 19.68, 17.21, 15.37, 10.61])
spgl_bpdn_ssim = np.array([0.904, 0.830, 0.675, 0.556, 0.474, 0.406, 0.211])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([32.27, 28.43, 23.07, 19.75, 17.49, 15.73, 10.97])
spgl_lasso_ssim = np.array([0.908, 0.832, 0.677, 0.561, 0.481, 0.416, 0.220])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([32.21, 28.40, 22.94, 19.61, 17.26, 15.37, 10.68])
elastic_net_ssim = np.array([0.910, 0.833, 0.672, 0.557, 0.474, 0.405, 0.211])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.subplot(1, 2, 1)
plt.plot(sigma, spgl_bpdn_psnr, label='SPGL_BPDN PSNR', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='SPGL_LASSO PSNR', marker='o')
plt.plot(sigma, elastic_net_psnr, label='ELASTIC_Net PSNR', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('PSNR')
plt.title('PSNR vs Noise Level')
plt.legend()
plt.grid(True)

# Plot SSIM for all methods
plt.subplot(1, 2, 2)
plt.plot(sigma, spgl_bpdn_ssim, label='SPGL_BPDN SSIM', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='SPGL_LASSO SSIM', marker='o')
plt.plot(sigma, elastic_net_ssim, label='ELASTIC_Net SSIM', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('SSIM')
plt.title('SSIM vs Noise Level: ')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Image1: Fruits

# %%
Image= 'Fruits'

# Noise levels (σ)
sigma = np.array([5, 10, 20, 30, 40, 50, 100])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([35.45, 29.32, 22.95, 19.66, 17.45, 15.82, 11.07])
spgl_bpdn_ssim = np.array([0.625, 0.419, 0.238, 0.161, 0.120, 0.092, 0.034])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([35.62, 29.32, 23.33, 20.05, 17.83, 16.23, 11.39])
spgl_lasso_ssim = np.array([0.634, 0.420, 0.249, 0.169, 0.124, 0.096, 0.036])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([35.45, 29.08, 23.22, 19.78, 17.55, 15.84, 11.16])
elastic_net_ssim = np.array([0.624, 0.414, 0.244, 0.163, 0.118, 0.090, 0.034])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.subplot(1, 2, 1)
plt.plot(sigma, spgl_bpdn_psnr, label='SPGL_BPDN PSNR', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='SPGL_LASSO PSNR', marker='o')
plt.plot(sigma, elastic_net_psnr, label='ELASTIC_Net PSNR', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('PSNR')
plt.title('PSNR vs Noise Level')
plt.legend()
plt.grid(True)

# Plot SSIM for all methods
plt.subplot(1, 2, 2)
plt.plot(sigma, spgl_bpdn_ssim, label='SPGL_BPDN SSIM', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='SPGL_LASSO SSIM', marker='o')
plt.plot(sigma, elastic_net_ssim, label='ELASTIC_Net SSIM', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('SSIM')
plt.title('SSIM vs Noise Level: ')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Image7: wheel

# %%
Image= 'Wheel'

# Noise levels (σ)
sigma = np.array([5, 10, 20, 30, 40, 50])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([35.00, 29.28, 23.38, 20.11, 17.75, 15.99])
spgl_bpdn_ssim = np.array([0.763, 0.623, 0.469, 0.376, 0.301, 0.249])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([35.15, 29.32, 23.50, 20.35, 17.97, 16.15])
spgl_lasso_ssim = np.array([0.770, 0.627, 0.471, 0.377, 0.305, 0.250])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([34.82, 29.06, 23.43, 20.17, 17.78, 16.05])
elastic_net_ssim = np.array([0.758, 0.622, 0.471, 0.375, 0.300, 0.248])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.subplot(1, 2, 1)
plt.plot(sigma, spgl_bpdn_psnr, label='SPGL_BPDN PSNR', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='SPGL_LASSO PSNR', marker='o')
plt.plot(sigma, elastic_net_psnr, label='ELASTIC_Net PSNR', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('PSNR')
plt.title('PSNR vs Noise Level')
plt.legend()
plt.grid(True)

# Plot SSIM for all methods
plt.subplot(1, 2, 2)
plt.plot(sigma, spgl_bpdn_ssim, label='SPGL_BPDN SSIM', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='SPGL_LASSO SSIM', marker='o')
plt.plot(sigma, elastic_net_ssim, label='ELASTIC_Net SSIM', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('SSIM')
plt.title('SSIM vs Noise Level: ')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
Image= 'Wheel'

# Noise levels (σ)
sigma = np.array([5, 10, 20])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([35.00, 29.28, 23.38])
spgl_bpdn_ssim = np.array([0.763, 0.623, 0.469])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([35.15, 29.32, 23.50])
spgl_lasso_ssim = np.array([0.770, 0.627, 0.471])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([34.82, 29.06, 23.43])
elastic_net_ssim = np.array([0.758, 0.622, 0.471])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.subplot(1, 2, 1)
plt.plot(sigma, spgl_bpdn_psnr, label='SPGL_BPDN PSNR', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='SPGL_LASSO PSNR', marker='o')
plt.plot(sigma, elastic_net_psnr, label='ELASTIC_Net PSNR', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('PSNR')
plt.title('PSNR vs Noise Level')
plt.legend()
plt.grid(True)

# Plot SSIM for all methods
plt.subplot(1, 2, 2)
plt.plot(sigma, spgl_bpdn_ssim, label='SPGL_BPDN SSIM', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='SPGL_LASSO SSIM', marker='o')
plt.plot(sigma, elastic_net_ssim, label='ELASTIC_Net SSIM', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('SSIM')
plt.title('SSIM vs Noise Level: ')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Image 9: Tapeholder

# %%
Image= 'TapeHolder'

# Noise levels (σ)
sigma = np.array([5, 10, 20])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([0,0,0])
spgl_bpdn_ssim = np.array([0,0,0])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([0,29.37,23.75])
spgl_lasso_ssim = np.array([0,0.337,0.208])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([34.47,0,0])
elastic_net_ssim = np.array([0.472,0,0])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.subplot(1, 2, 1)
plt.plot(sigma, spgl_bpdn_psnr, label='SPGL_BPDN PSNR', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='SPGL_LASSO PSNR', marker='o')
plt.plot(sigma, elastic_net_psnr, label='ELASTIC_Net PSNR', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('PSNR')
plt.title('PSNR vs Noise Level')
plt.legend()
plt.grid(True)

# Plot SSIM for all methods
plt.subplot(1, 2, 2)
plt.plot(sigma, spgl_bpdn_ssim, label='SPGL_BPDN SSIM', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='SPGL_LASSO SSIM', marker='o')
plt.plot(sigma, elastic_net_ssim, label='ELASTIC_Net SSIM', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('SSIM')
plt.title('SSIM vs Noise Level: ')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
Image= 'CameraMan NLM'

# Noise levels (σ)
sigma = np.array([5, 10, 20, 30, 40, 50])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([34.28, 28.45, 22.51, 19.05, 16.64, 14.90])
spgl_bpdn_ssim = np.array([0.598, 0.468, 0.344, 0.274, 0.227, 0.191])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([34.31, 28.64, 22.63, 19.12, 16.70, 14.92])
spgl_lasso_ssim = np.array([0.609, 0.478, 0.345, 0.277, 0.225, 0.189])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([34.31, 28.50, 22.56, 19.10, 16.71, 14.893])
elastic_net_ssim = np.array([0.610, 0.470, 0.345, 0.274, 0.227, 0.192])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.subplot(1, 2, 1)
plt.plot(sigma, spgl_bpdn_psnr, label='BPDN PSNR', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='NNC_LASSO PSNR', marker='o')
plt.plot(sigma, elastic_net_psnr, label='NN_LASSO PSNR', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('PSNR')
plt.title('PSNR vs Noise Level: NLM Denoising')
plt.legend()
plt.grid(True)

# Plot SSIM for all methods
plt.subplot(1, 2, 2)
plt.plot(sigma, spgl_bpdn_ssim, label='BPDN SSIM', marker='o')
plt.plot(sigma, spgl_lasso_ssim, label='NNC_LASSO SSIM', marker='o')
plt.plot(sigma, elastic_net_ssim, label='NN_LASSO SSIM', marker='o')
plt.xlabel('Standard deviation (σ, in pixels) for Image in [0,255]')
plt.ylabel('SSIM')
plt.title('SSIM vs Noise Level: NLM Denoising')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# The comparison of NLM in the cluster, with the NLM baseline

# %%
Image= 'CameraMan NLM'

# Noise levels (σ)
sigma = np.array([5, 10, 20, 30, 40, 50])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([34.28, 28.45, 22.51, 19.05, 16.64, 14.90])
spgl_bpdn_ssim = np.array([0.607, 0.468, 0.344, 0.274, 0.227, 0.191])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([34.31, 28.64, 22.63, 19.12, 16.70, 14.92])
spgl_lasso_ssim = np.array([0.609, 0.478, 0.345, 0.277, 0.225, 0.189])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([34.31, 28.50, 22.56, 19.10, 16.71, 14.893])
elastic_net_ssim = np.array([0.610, 0.470, 0.345, 0.274, 0.227, 0.192])

#NLM Denoising with h=0.01, window 250. Had a better result for sigma=10 with h=0.009 and window 300.
NLM_psnr = np.array([27.8, 23.37, 19.89, 17.92, 15.73, 14.26])
NLM_ssim = np.array([0.325, 0.243, 0.156, 0.123, 0.089, 0.059])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods

plt.plot(sigma, spgl_bpdn_psnr, label='BPDN', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='NNC_LASSO', marker='o')
plt.plot(sigma, elastic_net_psnr, label='NN_LASSO', marker='o')
plt.plot(sigma, NLM_psnr, label='NLM', marker='o')
plt.xlabel('AWGN standard deviation σ (in pixels)', fontsize= 20)
plt.ylabel('PSNR',fontsize= 20)
plt.title('PSNR vs Noise Level: NLM Denoising')
plt.legend()
plt.grid(True)
plt.legend(fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Comparison of another version of Patch SUbspace Projection: adding the mean vector explicitly

# %%
Image= 'CameraMan NLM'

# Noise levels
sigma = np.array([5, 10, 20, 30, 40, 50])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([31.78, 28.49, 22.94, 19.41, 16.91, 15.27])
spgl_bpdn_ssim = np.array([0.595, 0.466, 0.347, 0.276, 0.228, 0.191])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([33.21, 29.16, 23.58, 20.04, 17.45, 15.73])
spgl_lasso_ssim = np.array([0.608, 0.475, 0.352, 0.278, 0.227, 0.195])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([32.24, 28.90, 23.05, 19.59, 17.14, 15.19])
elastic_net_ssim = np.array([0.591, 0.473, 0.347, 0.277, 0.229, 0.191])

#NLM Denoising with h=0.01, window 250. Had a better result for sigma=10 with h=0.009 and window 300.
NLM_psnr = np.array([27.8, 23.37, 19.89, 17.92, 15.73, 14.26])
NLM_ssim = np.array([0.325, 0.243, 0.156, 0.123, 0.089, 0.059])

#ELASTIC_Net with explicit mean during PCA projection PSNR/SSIM
elastic_net_wmean_psnr = np.array([6.33, 6.34, 6.23, 6.15, 5.91, 5.83])
elastic_net_wmean_ssim = np.array([0.320, 0.299, 0.219, 0.180, 0.149, 0.132])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.plot(sigma, spgl_bpdn_psnr, label='BPDN', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='NNC_LASSO', marker='o')
plt.plot(sigma, elastic_net_psnr, label='NN_LASSO', marker='o')
plt.plot(sigma, NLM_psnr, label='NLM', marker='o')
plt.plot(sigma, elastic_net_wmean_psnr, label='NC_LASSO_MeanEnforced', marker='o')
plt.xlabel('AWGN standard deviation σ (in pixels)', fontsize= 20)
plt.ylabel('PSNR',fontsize= 20)
plt.title('PSNR vs Noise Level: Patched Subspace Projection in each cluster')
plt.legend()
plt.grid(True)
plt.legend(fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Show the plot
plt.tight_layout()
plt.show()

# %%
Image= 'CameraMan NLM'

# Noise levels (σ)
sigma = np.array([5, 10, 20, 30, 40, 50])

# SPGL_BPDN PSNR/SSIM
spgl_bpdn_psnr = np.array([34.28, 28.45, 22.51, 19.05, 16.64, 14.90])
spgl_bpdn_ssim = np.array([0.607, 0.468, 0.344, 0.274, 0.227, 0.191])

# SPGL_LASSO PSNR/SSIM
spgl_lasso_psnr = np.array([34.31, 28.64, 22.63, 19.12, 16.70, 14.92])
spgl_lasso_ssim = np.array([0.609, 0.478, 0.345, 0.277, 0.225, 0.189])

# ELASTIC_Net PSNR/SSIM
elastic_net_psnr = np.array([34.31, 28.50, 22.56, 19.10, 16.71, 14.893])
elastic_net_ssim = np.array([0.610, 0.470, 0.345, 0.274, 0.227, 0.192])

#NLM Denoising with h=0.01, window 250. Had a better result for sigma=10 with h=0.009 and window 300.
NLM_psnr = np.array([27.8, 23.37, 19.89, 17.92, 15.73, 14.26])
NLM_ssim = np.array([0.325, 0.243, 0.156, 0.123, 0.089, 0.059])

#ELASTIC_Net with explicit mean during PCA projection PSNR/SSIM
elastic_net_wmean_psnr = np.array([6.33, 6.34, 6.23, 6.15, 5.91, 5.83])
elastic_net_wmean_ssim = np.array([0.320, 0.299, 0.219, 0.180, 0.149, 0.132])

# Create the plot
plt.figure(figsize=(12, 6))

# Plot PSNR for all methods
plt.plot(sigma, spgl_bpdn_psnr, label='BPDN', marker='o')
plt.plot(sigma, spgl_lasso_psnr, label='NNC_LASSO', marker='o')
plt.plot(sigma, elastic_net_psnr, label='NN_LASSO', marker='o')
plt.plot(sigma, NLM_psnr, label='NLM', marker='o')
plt.plot(sigma, elastic_net_wmean_psnr, label='NN_LASSO_MeanEnforced', marker='o')
plt.xlabel('AWGN standard deviation σ (in pixels)', fontsize= 20)
plt.ylabel('PSNR',fontsize= 20)
plt.title('PSNR vs Noise Level: NLM Denoising in each cluster')
plt.legend()
plt.grid(True)
plt.legend(fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Create noisy images

# %%
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
from skimage.restoration import denoise_nl_means, estimate_sigma
from skimage.metrics import structural_similarity as ssim
image_number = 6
# dimensionality (N) of subspace = 64
tile_w = 8
step_size = 8 
std_dev = 50

results_dir = "results/FixedNum_spgl_lasso/tilw%d_step%d_noise%d"%(tile_w,step_size,std_dev)
if not os.path.exists(results_dir):
    os.makedirs(results_dir)

 
image = cv2.imread(f"Dataset/Image{image_number}.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(image.shape)
mindim = np.min(image.shape)
mindim = int((mindim // tile_w) * tile_w)
image = image[:mindim, :mindim]
print("image shape: ", image.shape)

output_file = open(results_dir+'/image_%d noise_performance.txt'%(image_number), 'a')

noisy_image = np.uint8(np.clip(image + np.random.normal(scale=std_dev, size=image.shape), 0, 255))
print('PSNR_noisesig_%d'%(std_dev), cv2.PSNR(image.astype(np.float32), noisy_image.astype(np.float32)), file=output_file)

ssim_value, ssim_map = ssim(noisy_image.astype(np.float32), image.astype(np.float32), full=True)
print('ssim_value_noisesig_%d'%(std_dev), ssim_value, file=output_file)
output_file.close()

plt.imshow(noisy_image, cmap='gray', vmin=0, vmax=255)  # Display in grayscale
plt.axis('off')  # Turn off axis labels if desired
plt.savefig(os.path.join(results_dir, "image_%d_NoisyImage_Gray.png" % image_number), bbox_inches='tight', pad_inches=0)  # Save without colorbar
plt.close()
# Out:
# (256, 256)
# image shape:  (256, 256)
